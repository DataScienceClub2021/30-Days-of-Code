# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 20 // o(1) 1 + n + n +n  + 1 + 1 +1 = 3n +4 =n 
for i in range(0,n):o(n)

for j in range(0,n):

for j in range(0,n):

    print("Ahmed")
a  = 10 //1
b = 20 //1
print(a+b) //1

# %%
n = 20 // o(1) 1 + n + n +n  + 1 + 1 +1 = n ^ 4
for i in range(0,n):o(n)
  for j in range(0,n):
    for j in range(0,n):
      for j in range(0,n):

    print("Ahmed")
a  = 10 //1
b = 20 //1
print(a+b) //1

# %%
import math
for i in range(0,math.sqrt(n)): // n
    

    print("Ahmed")
a  = 10 //1
b = 20 //1
print(a+b) //1
